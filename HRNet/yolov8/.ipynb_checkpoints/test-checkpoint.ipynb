# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.144 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (Quadro RTX 8000, 48586MiB)
# Setup complete ✅ (80 CPUs, 376.5 GB RAM, 855.0/937.8 GB disk)

# %%
from ultralytics import YOLO
import pandas as pd

# 1. 训练
model = YOLO("yolov8n-pose.pt")

# Load a mode
# Train the model
results = model.train(
    data="bsf1.yaml",
    epochs=20,
    imgsz=640,
    device=0,          # 改为你的GPU
    verbose=True,
    workers=0
)

# 2. 验证（直接调用，方便看分数）
metrics = model.val()

# 3. 打印训练过程指标
csv_path = model.trainer.save_dir + "/results.csv"  # 自动获取exp目录
df = pd.read_csv(csv_path)
cols = ["epoch", "lr/pg0", "train/box_loss", "train/kpt_loss", "metrics/mAP_0.5", "metrics/mAP_0.5:kpt"]
print("{:^6} | {:^10} | {:^12} | {:^12} | {:^12} | {:^15}".format("Epoch", "LR", "Box Loss", "Kpt Loss", "mAP@0.5", "mAP@0.5:kpt"))
print("-" * 80)
for _, row in df.iterrows():
    print("{:^6} | {:^10.6f} | {:^12.4f} | {:^12.4f} | {:^12.4f} | {:^15.4f}".format(
        int(row["epoch"]), row["lr/pg0"], row["train/box_loss"], row["train/kpt_loss"], row["metrics/mAP_0.5"], row["metrics/mAP_0.5:kpt"]
    ))
# Out:
# Ultralytics 8.3.144 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (Quadro RTX 8000, 48586MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=bsf1.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train26, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/pose/train26, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[2, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    823429  ultralytics.nn.modules.head.Pose             [1, [2, 3], [64, 128, 256]]
# YOLOv8n-pose summary: 144 layers, 3,082,965 parameters, 3,082,949 gradients, 8.4 GFLOPs
#
# Transferred 361/397 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.2±0.0 ms, read: 1388.2±69.1 MB/s, size: 4231.6 KB)
# train: Scanning /home/hope/R&D_Pro/HRNet/data/bsf2023/labels/train... 1246 images, 0 backgrounds, 1246 corrupt: 100%|██████████| 1246/1246 [00:00<00:00, 1526.20it/s]
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-12-29.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-14-33.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-20-10.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-22-58.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-32-24.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-35-22.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-41-15.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-44-40.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-15-51-21.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-08-43.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-09-37.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-14-40.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-21-11.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-26-54.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-29-38.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-34-34.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-37-40.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-10-16-42-22.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-10-34-14.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-13-30-29.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-13-34-01.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-13-49-46.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-13-53-07.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-13-58-46.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-19-59.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-20-24.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-20-57.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-22-11.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-22-46.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-23-15.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-46-49.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-47-33.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-48-24.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-49-13.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-49-22.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-50-09.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-51-58.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-52-41.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-53-58.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-54-04.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-14-59-41.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-51-04.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-52-06.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-53-02.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-53-53.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-54-36.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-55-26.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-56-26.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-58-55.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-15-59-48.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-50-28.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-51-23.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-52-30.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-53-07.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-53-38.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-53-54.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-16-55-25.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-17-00-25.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-17-10-46.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-17-11-55.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-17-12-30.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-11-17-13-21.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-06-06.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-07-04.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-08-10.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-09-53.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-10-45.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-11-24.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-12-06.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-12-40.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-12-53.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-13-37.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-15-18.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-15-51.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-16-22.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-16-51.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-18-19.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-19-49.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-21-14.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-21-47.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-12-22-48.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-15-39-00.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-15-39-13.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-15-39-43.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-15-41-48.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-15-42-13.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-15-43-19.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-16-58-28.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-16-59-35.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-00-12.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-00-43.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-00-49.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-02-21.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-03-21.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-08-06.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-08-22.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-09-03.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-09-24.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-10-40.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-11-28.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-12-19.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-13-30.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-14-15.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-15-09.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-15-18.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-20-10.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-21-04.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-21-31.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-12-17-22-03.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-39-12.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-40-13.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-40-42.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-41-04.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-41-28.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-41-57.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11-42-22.jpg: ignoring corrupt image/label: labels require 11 columns each
# train: /home/hope/R&D_Pro/HRNet/data/bsf2023/images/train/2023-07-13-11
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/engine/model.py:796, in Model.train(self, trainer, **kwargs)
#     793     self.model = self.trainer.model
#     795 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 796 self.trainer.train()
#     797 # Update model and cfg after training
#     798 if RANK in {-1, 0}:
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/engine/trainer.py:227, in BaseTrainer.train(self)
#     224         ddp_cleanup(self, str(file))
#     226 else:
# --> 227     self._do_train(world_size)
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/engine/trainer.py:348, in BaseTrainer._do_train(self, world_size)
#     346 if world_size > 1:
#     347     self._setup_ddp(world_size)
# --> 348 self._setup_train(world_size)
#     350 nb = len(self.train_loader)  # number of batches
#     351 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/engine/trainer.py:307, in BaseTrainer._setup_train(self, world_size)
#     305 # Dataloaders
#     306 batch_size = self.batch_size // max(world_size, 1)
# --> 307 self.train_loader = self.get_dataloader(
#     308     self.data["train"], batch_size=batch_size, rank=LOCAL_RANK, mode="train"
#     309 )
#     310 if RANK in {-1, 0}:
#     311     # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
#     312     self.test_loader = self.get_dataloader(
#     313         self.data.get("val") or self.data.get("test"),
#     314         batch_size=batch_size if self.args.task == "obb" else batch_size * 2,
#     315         rank=-1,
#     316         mode="val",
#     317     )
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/models/yolo/detect/train.py:83, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#      81 assert mode in {"train", "val"}, f"Mode must be 'train' or 'val', not {mode}."
#      82 with torch_distributed_zero_first(rank):  # init dataset *.cache only once if DDP
# ---> 83     dataset = self.build_dataset(dataset_path, mode, batch_size)
#      84 shuffle = mode == "train"
#      85 if getattr(dataset, "rect", False) and shuffle:
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/models/yolo/detect/train.py:66, in DetectionTrainer.build_dataset(self, img_path, mode, batch)
#      54 """
#      55 Build YOLO Dataset for training or validation.
#      56
#    (...)
#      63     (Dataset): YOLO dataset object configured for the specified mode.
#      64 """
#      65 gs = max(int(de_parallel(self.model).stride.max() if self.model else 0), 32)
# ---> 66 return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, rect=mode == "val", stride=gs)
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/data/build.py:117, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#     115 """Build and return a YOLO dataset based on configuration parameters."""
#     116 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# --> 117 return dataset(
#     118     img_path=img_path,
#     119     imgsz=cfg.imgsz,
#     120     batch_size=batch,
#     121     augment=mode == "train",  # augmentation
#     122     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#     123     rect=cfg.rect or rect,  # rectangular batches
#     124     cache=cfg.cache or None,
#     125     single_cls=cfg.single_cls or False,
#     126     stride=int(stride),
#     127     pad=0.0 if mode == "train" else 0.5,
#     128     prefix=colorstr(f"{mode}: "),
#     129     task=cfg.task,
#     130     classes=cfg.classes,
#     131     data=data,
#     132     fraction=cfg.fraction if mode == "train" else 1.0,
#     133 )
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/data/dataset.py:88, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      86 self.data = data
#      87 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 88 super().__init__(*args, channels=self.data["channels"], **kwargs)
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/data/base.py:116, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction, channels)
#     114 self.cv2_flag = cv2.IMREAD_GRAYSCALE if channels == 1 else cv2.IMREAD_COLOR
#     115 self.im_files = self.get_img_files(self.img_path)
# --> 116 self.labels = self.get_labels()
#     117 self.update_labels(include_class=classes)  # single_cls and include_class
#     118 self.ni = len(self.labels)  # number of images
#
# File ~/.conda-2024.02/envs/yolo/lib/python3.8/site-packages/ultralytics/data/dataset.py:188, in YOLODataset.get_labels(self)
#     186 labels = cache["labels"]
#     187 if not labels:
# --> 188     raise RuntimeError(
#     189         f"No valid images found in {cache_path}. Images with incorrectly formatted labels are ignored. {HELP_URL}"
#     190     )
#     191 self.im_files = [lb["im_file"] for lb in labels]  # update im_files
#     193 # Check if the dataset is all boxes or all segments
#
# RuntimeError: No valid images found in /home/hope/R&D_Pro/HRNet/data/bsf2023/labels/train.cache. Images with incorrectly formatted labels are ignored. See https://docs.ultralytics.com/datasets for dataset formatting guidance.

# %%
import os

root = '/home/hope/R&D_Pro/HRNet/data/bsf2023'
img_dir = os.path.join(root, 'train')
label_dir = os.path.join(root, 'labels/train')
print('图片数:', len([f for f in os.listdir(img_dir) if f.endswith('.jpg')]))
print('标签数:', len([f for f in os.listdir(label_dir) if f.endswith('.txt')]))

bad = []
for txt in os.listdir(label_dir):
    if txt.endswith('.txt'):
        with open(os.path.join(label_dir, txt)) as f:
            lines = [l.strip() for l in f.readlines()]
            if len(lines) != 1:
                bad.append(txt)
            else:
                arr = lines[0].split()
                if len(arr) != 7:
                    bad.append(txt)
print('格式有误的标签文件:', bad[:5], '共', len(bad))
# Out:
# 图片数: 1246
# 标签数: 1246
# 格式有误的标签文件: [] 共 0

# %%
import os

img_root = '/home/hope/R&D_Pro/HRNet/data/bsf2023'
train_txt = os.path.join(img_root, 'train.txt')

with open(train_txt) as f:
    lines = [l.strip() for l in f.readlines()]
bad = [l for l in lines if not os.path.isfile(os.path.join(img_root, l))]
print('train.txt里实际不存在的图片:', bad)
print('共计:', len(bad))

# 再查一遍val
val_txt = os.path.join(img_root, 'val.txt')
with open(val_txt) as f:
    vlines = [l.strip() for l in f.readlines()]
vbad = [l for l in vlines if not os.path.isfile(os.path.join(img_root, l))]
print('val.txt里实际不存在的图片:', vbad)
print('共计:', len(vbad))
# Out:
# train.txt里实际不存在的图片: []
# 共计: 0
# val.txt里实际不存在的图片: []
# 共计: 0

# %%
import os

root = '/home/hope/R&D_Pro/HRNet/data/bsf2023'
for subset in ['train', 'val']:
    img_dir = os.path.join(root, 'images', subset)
    label_dir = os.path.join(root, 'labels', subset)
    imgs = set([os.path.splitext(f)[0] for f in os.listdir(img_dir) if f.endswith('.jpg')])
    labels = set([os.path.splitext(f)[0] for f in os.listdir(label_dir) if f.endswith('.txt')])
    print(f'[{subset}] 没有标签的图片:', imgs - labels)
    print(f'[{subset}] 没有图片的标签:', labels - imgs)
# Out:
# [train] 没有标签的图片: set()
# [train] 没有图片的标签: set()
# [val] 没有标签的图片: set()
# [val] 没有图片的标签: set()
